# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 对f(x)的Jacobian矩阵做SVD分解

# %%
test_id = "long_term_forecast_data_mean_996_37_iTransformer_QBO_ftM_sl24_pl24_dm512_nh8_el4_dl1_df512_fc3_ebtimeF_dtTrue_Exp_0"

# %%
jacs = {}
for i in range(0, 940, 25):
    str_i = f'{i:04d}'
    jacs[i] = np.load(f'../results/jacobian/{test_id}/jac_{str_i}.npy')

# %%
sns.heatmap(np.tanh(jacs[0].reshape(24*36, -1)))

# %%
u, s, vt = np.linalg.svd(jacs[50].reshape(24*36, -1).astype(float))

# %%
u, s, vt = np.linalg.svd(jacs[25].reshape(24*36, -1).astype(float))
plt.plot(np.log(s))
plt.grid()

# %%
u, s, vt = np.linalg.svd(jacs[850].reshape(24*36, -1).astype(float))
plt.plot(np.log(s))
plt.grid()

# %%
test_id = "long_term_forecast_data_mean_996_37_iTransformer_QBO_ftM_sl12_pl12_dm512_nh8_el4_dl1_df512_fc3_ebtimeF_dtTrue_Exp_0"
jacs = {}
for i in range(0, 940, 25):
    str_i = f'{i:04d}'
    jacs[i] = np.load(f'../results/jacobian/{test_id}/jac_{str_i}.npy')
    
    u, s, vt = np.linalg.svd(jacs[i].reshape(12*36, -1).astype(float))
    plt.plot(np.log(s), label=)
    plt.grid()

# %%
996/12
